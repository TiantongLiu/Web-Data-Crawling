# %%
import requests
import time
from bs4 import BeautifulSoup
headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8"
}
url='http://www.ziroom.com/z/'
page='p'

for i in range(1,5):
    i=str(i)
    a=(url+'p'+i+'/')
    r=requests.get(url=a,headers=headers)
    html=r.content
    time.sleep(2)
    zr=BeautifulSoup(html,'html.parser')
    price=zr.findAll('div','price')
    pr=[]
    for a in price:
        totalprice=a.span.num
        pr.append(totalprice)
pr

# %%
import requests
import re
from bs4 import BeautifulSoup

def getHTML(url):
    try:
        re=requests.get(url)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return re.text
    except:
        print('')
def priceinfo(info,html):
    info=[]
    pricelist=re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
    titlelist=re.findall(r'\"raw_title\"\:\".*?\"',html)
    for i in range(len(price)):
        price=eval(pricelist[i].split(':')[1])
        title=eval(titlelist[i].split(':')[1])
    return info.append([price,title])
def printlist(info):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format('序号','价格','名称'))
    for i in info:
        count=count+1
        print(tplt.format(count,g[1],g[2]))

def main():
    depth=5
    goods='书包'
    start_url='https://world.taobao.com/'+'goods'
    info=[]
    for i in range(depth):
        try:
            url=start_url+'&s='+'str(44*i)'
            html=getHTML(url)
            info=priceinfo(info,html)
        except:
            continue
    printlist(info)
 
main()
# Out:
# 序号  	价格      	名称

# %%
#CrowTaobaoPrice.py
import requests
import re
 
def getHTMLText(url):
    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""
     
def parsePage(ilt, html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"',html)
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([price , title])
    except:
        print("")
 
def printGoodsList(ilt):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号", "价格", "商品名称"))
    count = 0
    for g in ilt:
        count = count + 1
        print(tplt.format(count, g[0], g[1]))
         
def main():
    goods = '书包'
    depth = 3
    start_url = 'https://s.taobao.com/search?q=' + goods
    infoList = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(infoList, html)
        except:
            continue
    printGoodsList(infoList)
     
main()
# Out:
# 序号  	价格      	商品名称

# %%
import requests
import re
 
def getHTMLText(url):
    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""
     
def parsePage(ilt, html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"',html)
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([price , title])
    except:
        print("")
 
def printGoodsList(ilt):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号", "价格", "商品名称"))
    count = 0
    for g in ilt:
        count = count + 1
        print(tplt.format(count, g[0], g[1]))
         
def main():
    goods = '书包'
    depth = 3
    start_url = 'https://s.taobao.com/search?q=' + goods
    infoList = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(infoList, html)
        except:
            continue
    printGoodsList(infoList)
     
main()
# Out:
# 序号  	价格      	商品名称

# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.83 Safari/535.11"}
re=requests.get('https://www.douban.com/',headers=headers)
re.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(re.text,'html.parser')

# %%
list=soup.find_all('div','title')

# %%
list
# Out:
# [<div class="title">
#  <a href="https://www.douban.com/note/768469476/">闽侯的木拱廊桥</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/echofans/">我爱三毛</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/shafake/">沙发客</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/liucixin/">刘慈欣</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/20618/">西双版纳</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/402725/">记事本圆梦小组</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/dashan/">搭讪学</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/170177/">这辈子一定要做几件疯狂的事</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/cuthair/">自己给自己剪头发</a>
#  </div>, <div class="title">
#  <a href="https://www.douban.com/group/83759/">我们就是要做衣服给自己穿</a>
#  </div>, <div class="title">
# ...

# %%
data=[]
for s in list:
    content=s.text.replace('\n','')
    data.append(content)
data
# Out:
# ['回乌鲁木齐过节和结婚',
#  '我爱三毛',
#  '沙发客',
#  '刘慈欣',
#  '西双版纳',
#  '记事本圆梦小组',
#  '搭讪学',
#  '这辈子一定要做几件疯狂的事',
#  '自己给自己剪头发',
#  '我们就是要做衣服给自己穿',
#  '熔炉',
#  '万重山',
#  '愤怒',
#  '第三人',
#  '刹那',
#  '桐花落尽II',
#  '大唐驭妖记',
#  '妻子是制片人',
#  '              1. 近人可读',
#  '              2. EMERGING',
#  '              3. 孙燕姿出道20周年惊喜直播专辑',
#  '              4. 莲',
#  "              5. What's Your Pleasure",
#  '              6. Rough And Rowdy Ways',
#  '              7. 헹가래[Heng:garæ]',
#  '              8. ONEIRIC DIARY',
#  '流行民谣|想听民谣，就听听这...',
#  '【欧美金曲|女歌手】超酷歌唱...',
#  '【崩溃向】在KTV唱这些歌的人...',
#  '自己一人时也可以很惬意',
#  '这个有什么用嘞',
#  '午安🗼']

# %%
import pandas as pd
df=pd.DataFrame()
df['文本内容']=data
df
# Out:
#                                      文本内容
# 0                              回乌鲁木齐过节和结婚
# 1                                    我爱三毛
# 2                                     沙发客
# 3                                     刘慈欣
# 4                                    西双版纳
# 5                                 记事本圆梦小组
# 6                                     搭讪学
# 7                           这辈子一定要做几件疯狂的事
# 8                                自己给自己剪头发
# 9                            我们就是要做衣服给自己穿
# 10                                     熔炉
# 11                                    万重山
# 12                                     愤怒
# 13                                    第三人
# 14                                     刹那
# 15                                 桐花落尽II
# 16                                  大唐驭妖记
# 17                                 妻子是制片人
# 18                                1. 近人可读
# 19                            2. EMERGING
# 20                     3. 孙燕姿出道20周年惊喜直播专辑
# ...
